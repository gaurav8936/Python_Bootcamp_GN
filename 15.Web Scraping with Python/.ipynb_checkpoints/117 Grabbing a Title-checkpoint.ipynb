# %% [markdown]
# <font size = 8> Grabbing a Title

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# pip install requests

# %%
# pip install lxml -- this is used by beautiful soup library

# %%
# pip install bs4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests

# %%
import bs4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# https://en.wikipedia.org/wiki/Jonas_Salk

# %%
# View page source -- what wikipedia sends

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# trying to get the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# INSPECT

# %% [markdown]
# ![image.png](attachment:image.png)
