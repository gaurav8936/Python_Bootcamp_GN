# %% [markdown]
# <font size = 8> Coding Exercises, 10-19

# %% [markdown]
# <font color = red> Coding Exercise 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc():
    print('Hello World')

# %%
myfunc()
# Out:
# Hello World

# %% [markdown]
# <font color = red> Coding Exercise 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(name):
    print('Hello {}'.format(name))

# %%
myfunc('Ziba')
# Out:
# Hello Ziba
