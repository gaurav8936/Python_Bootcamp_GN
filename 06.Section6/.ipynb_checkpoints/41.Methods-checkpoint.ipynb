# %% [markdown]
# <font size = 8> Methods and the Python Documentation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = teal, size = 6> Methods are functions built into objects

# %%
mylist1 = [1,2,3]

# %% [markdown]
# ` Append Method `

# %%
mylist1.append(4)

# %%
mylist1
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ` Pop Method -- this removes last item on the list`

# %%
mylist1.pop()
# Out:
# 4

# %%
mylist1
# Out:
# [1, 2, 3]

# %% [markdown]
# ## finding help

# %% [markdown]
# <font color = red> use SHIFT+TAB

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = red> use the built-in HELP function

# %%
help(mylist1.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %% [markdown]
# <font color = red> review the docs on python.org

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ` The SECRETS Module -- one of the new things in 3.6.4 `

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <font size = 5, color = 'red'> The Standard Library

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = red, size = 4> Use StackOverflow in addition to Standard Library

# %% [markdown]
# ![image.png](attachment:image.png)
