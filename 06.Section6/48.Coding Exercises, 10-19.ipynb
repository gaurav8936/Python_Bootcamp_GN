# %% [markdown]
# <font size = 8> Coding Exercises, 10-19

# %% [markdown]
# <font color = red> Coding Exercise 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc():
    print('Hello World')

# %%
myfunc()
# Out:
# Hello World

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(name):
    print('Hello {}'.format(name))

# %%
myfunc('Ziba')
# Out:
# Hello Ziba

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(a):
    if a == True:
        return 'Inside'
    elif a == False:
        return 'Outside'

# %%
myfunc(1)
# Out:
# 'Inside'

# %%
myfunc(0)
# Out:
# 'Outside'

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(x,y,z):
    if z == True:
        return x
    elif z == False:
        return y

# %%
myfunc(100,200,0)
# Out:
# 200

# %%
myfunc(100,200,1)
# Out:
# 100

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(a,b):
    return a+b

# %%
myfunc(1,3)
# Out:
# 4

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_even(num):
    if num%2 == 0:
        return True
    else:
        return False

# %%
is_even(11)
# Out:
# False

# %% [markdown]
# ***

# %% [markdown]
# <font color = red> Coding Exercise 16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_greater(num1, num2):
    if num1 > num2:
        return True
    else:
        return False

# %%
is_greater(3,2)
# Out:
# True

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc5(*args):
    return sum(args)

# %%
myfunc5(4,5)
# Out:
# 9

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def myfunc(*args):
    mylist = []
    for n in args:
        if n%2 == 0:
            mylist.append(n)
    else:
        pass
    return mylist
#    else:
#        return ""

# %%
myfunc(1,2,3,4,5,6)
# Out:
# [2, 4, 6]
