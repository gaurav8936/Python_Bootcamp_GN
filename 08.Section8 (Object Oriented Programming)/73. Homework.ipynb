# %% [markdown]
# <font size = 8> Homework Assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Distance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#slope

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
