# %% [markdown]
# <font size = 8> Object Oriented Programming - Introduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# append method
# index for tuples

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# also sort on a list

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# note the class keyword
# Objects are also called CLASSES in Python
### CLASSES ARE CAMEL CASE

# %% [markdown]
# <font color = red> Objects are also called CLASSES in Python

# %% [markdown]
# <font color = red> The def keyword is to define methods inside an object. This type of function inside an object is called a METHOD

# %%
# _init_ allows you to create an instance of the object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the self keyword tells python this isn't just some function, but rather a method connected to an object
