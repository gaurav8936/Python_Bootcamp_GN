# %% [markdown]
# <font size = 8> Game Logic Part 3

# %%
# Add random, list of suites and ranks

import random

# tuple (does not change)
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')

# tuple (does not change)
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', \
         'Ten', 'Jack', 'Queen', 'King', 'Ace')

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card():
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %% [markdown]
# ***

# %%
class Deck():
    
    def __init__(self):
        
        # deck should contain all 52 card objects
        self.all_cards = [] # this is an attribute 
                            # this starts off as an empty list
        
        # for al suits, create a rank
        for suit in suits   :
            for rank in ranks:
                
                #Create the card object
                
                created_card = Card(suit,rank)
                
                # Append the newely created card to the list
                self.all_cards.append(created_card)
    
    def shuffle(self):
        
        # remember that random.shuffle does not return anything
        # there is not return -- it is all in place
        
        random.shuffle(self.all_cards)
    
    def deal_one(self):
        
        #return a single card
        return self.all_cards.pop()

# %%
# class Player:
    
#     def __init__(self, name):
        
#         self.name = name
#         self.all_cards = [] #empty list for current hand of cards
    
#     def remove_one(self):
#         pass
    
    
#     def add_cards(self, new_cards):
#         pass
    
    
#     def __str__(self):
#         return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
new_player = Player("Ziba")

# %%
print(new_player)
# Out:
# Player Ziba has 0 cards

# %%
# Removing & adding cards cards

# %%
# 3 things to do
## add a single card object
## add multiple card objects
## remove a card object
##### we don't need to remove multiple cards as a list (instead us a for loop)


class Player:
    
    def __init__(self, name):
        
        self.name = name
        self.all_cards = [] #empty list for current hand of cards
    
    def remove_one(self):
        return self.all_cards.pop(0)
    
    
    def add_cards(self, new_cards):
        # new_cards can be a single card object or a list of card objects
        # for list of multiple card objects
        if type(new_cards)== type([]):
            self.all_cards.extend(new_cards)
        
        # for single card object
        else:
            self.all_cards.append(new_cards)
    
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
new_player = Player("Amy")

# %%
print(new_player)
# Out:
# Player Amy has 0 cards

# %% [markdown]
# ***

# %%
# create the deck

# %%
new_deck = Deck()

# %%
mycard = new_deck.deal_one()

# %%
print(mycard)
# Out:
# Ace of Clubs

# %% [markdown]
# ***

# %%
# add single card objext

new_player.add_cards(mycard)

# %%
print(new_player)
# Out:
# Player Amy has 1 cards

# %% [markdown]
# ***

# %%
print(new_player.all_cards[0])
# Out:
# Ace of Clubs

# %%
# notice the same card in the list

# %% [markdown]
# ***

# %%
# adding multiple card objects as a list

new_player.add_cards([mycard, mycard, mycard])

# %%
print(new_player)
# Out:
# Player Amy has 4 cards

# %% [markdown]
# ***

# %%
# Test the removal method

new_player.remove_one()

# %%
print(new_player)
# Out:
# Player Amy has 3 cards

# %% [markdown]
# ***

# %%
# GAME SETUP

# %%
player_one = Player("One")
player_two = Player("Two")


# create a new deck

new_deck = Deck()
new_deck.shuffle()


#SPLIT THE DECK BETWEEN PLAYERS
# shuffle deck
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
print(player_one.all_cards[0])
# Out:
# Two of Hearts

# %%
# start the game

game_on = True

# %%
# # WHILE GAME ON


# round_num = 0

# while game_on:
#     round_num += 1
#     print(f"Round {round_num}")

#     # check to see if player one is  out of cards
#     if len(player_one.all_cards) == 0:
#           print('Player One, out of cards! Player Two wins')
#           game_on = False
#           break
    
#     # check to see if player two is  out of cards
#     if len(player_two.all_cards) == 0:
#           print('Player Two, out of cards! Player One wins')
#           game_on = False
#           break

    
#     # Start a new round
          
#     player_one_cards = []   # this is the list of cards player leaves on the table
#                             # face down list of cards (remaining - not folded)
#                             # This is the list of cuvrrent cards in play
#                             # this is nto the same as player_one.all_cards (which 
#                             # is the full list)
    
#     # add from player_one.all_cards to player_one_cards
    
#     player_one_cards.append(player_one.remove_one())      
    
    
#     player_two_cards = []
          
    
#     # add from player_one.all_cards to player_one_cards
          
#     player_two_cards.append(player_two.remove_one())      
    
    
          
#     # WHILE AT WAR
# Out:
#   Input In [12]
#     print(f"Round {round_num}"")
#                                 ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# <font size = 6, color = red> Actual addition in this lesson

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # WHILE GAME ON


# round_num = 0

# while game_on:
#     round_num += 1
#     print(f"Round {round_num}")

#     # check to see if player one is  out of cards
#     if len(player_one.all_cards) == 0:
#           print('Player One, out of cards! Player Two wins')
#           game_on = False
#           break
    
#     # check to see if player two is  out of cards
#     if len(player_two.all_cards) == 0:
#           print('Player Two, out of cards! Player One wins')
#           game_on = False
#           break

    
#     # Start a new round
          
#     player_one_cards = []   # this is the list of cards player leaves on the table
#                             # face down list of cards (remaining - not folded)
#                             # This is the list of cuvrrent cards in play
#                             # this is nto the same as player_one.all_cards (which 
#                             # is the full list)
    
#     # add from player_one.all_cards to player_one_cards
    
#     player_one_cards.append(player_one.remove_one())      
    
    
#     player_two_cards = []
          
    
#     # add from player_one.all_cards to player_one_cards
          
#     player_two_cards.append(player_two.remove_one())      
    
    
          
#     # WHILE AT WAR
    
    
#     at_war = True
    
#     while at_war:
        
#         if player_one_cards[-1].value > player_two_cards([-1].value:
#             player_one.add_cards(player_one_cards)
#             # remember that .add_cards works for both single as well as multiple card objects
#             player_one.add_cards(player_two_cards)
            
#             at_war = False
      
                                                         
#      # check if player2 has won                                                    
                                                         
                                                         
#         if player_one_cards[-1].value < player_two_cards([-1].value:
                                                         
#             player_two.add_cards(player_one_cards)
#             # remember that .add_cards works for both single as well as multiple card objects
#             player_two.add_cards(player_two_cards)
            
#             at_war = False                                            
                                                         
#      else:
                                                             
#         print('WAR!')      
        
#         # optional logic to lose the game if player does not have enough cards
        
#         if len(player_one.all_cards) < 3:
#               print("Player One unable to continue playing war"
              
#               print("Player TWO WINS")      
                                                          
#               game_on = False
#               break
        
#         elif len(player_two.all_cards) < 3:
#               print("Player Two unable to continue playing war"
              
#               print("Player ONE WINS")      
                                                          
#               game_on = False
#               break
                    
#         else:
#               for num in range(3):
#                     player_one_cards.append(player_one.remove_one())
#                     player_two_cards.append(player_two.remove_one())
# Out:
#   Input In [3]
#     if player_one_cards[-1].value > player_two_cards([-1].value:
#                                                                ^
# SyntaxError: invalid syntax

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# WAR!
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# WAR!
# Round 41
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# WAR!
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# Round 87
# Round 88
# Round 89
# ...
