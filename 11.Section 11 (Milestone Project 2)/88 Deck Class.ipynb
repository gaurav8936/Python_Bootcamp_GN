# %% [markdown]
# <font size = 8> Deck Class

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# different from what we have seen in the past
# each variable in the deck class will contain a card object

# %%
# deal card with the pop method -- grabs from the top or bottom of the deck

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color = red> A class object (Deck) uses instances of another class (Card) -- we have not seen this before. This is neither inheritence or polymorphism

# %%
# Add random, list of suites and ranks

import random

# tuple (does not change)
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')

# tuple (does not change)
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', \
         'Ten', 'Jack', 'Queen', 'King', 'Ace')

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card():
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
two_hearts = Card("Hearts", "Two")

# %%
three_clubs = Card("Clubs", "Three")

# %%
two_hearts.value
# Out:
# 2

# %%
three_clubs.value
# Out:
# 3

# %%
# class Deck():
    
#     def __init__(self):
        
#         # deck should contain all 52 card objects
#         self.all_cards = [] # this is an attribute 
#                             # this starts off as an empty list
        
#         # for al suits, create a rank
#         for suit in suits   :
#             for rank in ranks:
                
#                 #Create the card object
                
#                 created_card = Card(suit,rank)
                
#                 # Append the newely created card to the list
#                 self.all_cards.append(created_card)

# %%
# create a brand new deck
new_deck = Deck()

# %%
new_deck.all_cards
# Out:
# [<__main__.Card at 0x7fd8c0882850>,
#  <__main__.Card at 0x7fd8c08823d0>,
#  <__main__.Card at 0x7fd8c0878b80>,
#  <__main__.Card at 0x7fd8c0898dc0>,
#  <__main__.Card at 0x7fd8a0993d90>,
#  <__main__.Card at 0x7fd8a0993520>,
#  <__main__.Card at 0x7fd8a0993670>,
#  <__main__.Card at 0x7fd8c08865b0>,
#  <__main__.Card at 0x7fd8c0886b20>,
#  <__main__.Card at 0x7fd8c0886850>,
#  <__main__.Card at 0x7fd8b1407e20>,
#  <__main__.Card at 0x7fd8b1407ac0>,
#  <__main__.Card at 0x7fd8b0b60190>,
#  <__main__.Card at 0x7fd8c08a0370>,
#  <__main__.Card at 0x7fd8c08a0220>,
#  <__main__.Card at 0x7fd8b0dac700>,
#  <__main__.Card at 0x7fd8b0dac550>,
#  <__main__.Card at 0x7fd8b0c34280>,
#  <__main__.Card at 0x7fd8c08c5310>,
#  <__main__.Card at 0x7fd8b13fed30>,
#  <__main__.Card at 0x7fd8b13fe9d0>,
#  <__main__.Card at 0x7fd8b13fe670>,
#  <__main__.Card at 0x7fd8b13fbf10>,
#  <__main__.Card at 0x7fd8b13fb760>,
#  <__main__.Card at 0x7fd8b13fb3d0>,
#  <__main__.Card at 0x7fd8b13fb130>,
#  <__main__.Card at 0x7fd8b13f7490>,
#  <__main__.Card at 0x7fd8b13f7fd0>,
#  <__main__.Card at 0x7fd8a0ae0a60>,
#  <__main__.Card at 0x7fd8a0ae0be0>,
#  <__main__.Card at 0x7fd8a0ae06a0>,
#  <__main__.Card at 0x7fd8a0ae0520>,
#  <__main__.Card at 0x7fd8a0ae00a0>,
#  <__main__.Card at 0x7fd8a0aed4c0>,
#  <__main__.Card at 0x7fd8a0aed940>,
#  <__main__.Card at 0x7fd8a0aedd30>,
#  <__main__.Card at 0x7fd8a0af64f0>,
#  <__main__.Card at 0x7fd8a0af6850>,
#  <__main__.Card at 0x7fd8a0b03d90>,
#  <__main__.Card at 0x7fd8a0b03790>,
#  <__main__.Card at 0x7fd8a0b3c160>,
#  <__main__.Card at 0x7fd8a0b3c490>,
#  <__main__.Card at 0x7fd8a0b23340>,
#  <__main__.Card at 0x7fd8a0b23b50>,
#  <__main__.Card at 0x7fd8a0b23f10>,
#  <__main__.Card at 0x7fd8a0b31ca0>,
#  <__main__.Card at 0x7fd8a0b312b0>,
#  <__main__.Card at 0x7fd8a0b31a00>,
#  <__main__.Card at 0x7fd8a0b4e040>,
#  <__main__.Card at 0x7fd8a0b4eb50>,
#  <__main__.Card at 0x7fd8a0b4eee0>,
#  <__main__.Card at 0x7fd8a0b49040>]

# %%
first_card = new_deck.all_cards[0]

# %%
first_card.value
# Out:
# 2

# %%
# you can print the list
print(first_card)
# Out:
# Two of Hearts

# %% [markdown]
# Bottom card

# %%
bottom_card = new_deck.all_cards[-1]

# %%
print(bottom_card)
# Out:
# Ace of Clubs

# %%
for card_object in new_deck.all_cards:
    print(card_object)
# Out:
# Two of Hearts
# Three of Hearts
# Four of Hearts
# Five of Hearts
# Six of Hearts
# Seven of Hearts
# Eight of Hearts
# Nine of Hearts
# Ten of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Two of Diamonds
# Three of Diamonds
# Four of Diamonds
# Five of Diamonds
# Six of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# Nine of Diamonds
# Ten of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# Two of Spades
# Three of Spades
# Four of Spades
# Five of Spades
# Six of Spades
# Seven of Spades
# Eight of Spades
# Nine of Spades
# Ten of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
# Two of Clubs
# Three of Clubs
# Four of Clubs
# Five of Clubs
# Six of Clubs
# Seven of Clubs
# Eight of Clubs
# Nine of Clubs
# Ten of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs

# %% [markdown]
# ***

# %%
# Shuffle a deck

# %%
# class Deck():
    
#     def __init__(self):
        
#         # deck should contain all 52 card objects
#         self.all_cards = [] # this is an attribute 
#                             # this starts off as an empty list
        
#         # for al suits, create a rank
#         for suit in suits   :
#             for rank in ranks:
                
#                 #Create the card object
                
#                 created_card = Card(suit,rank)
                
#                 # Append the newely created card to the list
#                 self.all_cards.append(created_card)
    
#     def shuffle(self):
        
#         # remember that random.shuffle does not return anything
#         # there is not return -- it is all in place
        
#         random.shuffle(self.all_cards)

# %%
new_deck2 = Deck()

# %%
new_deck2.all_cards
# Out:
# [<__main__.Card at 0x7fd8c0882b80>,
#  <__main__.Card at 0x7fd8c08822b0>,
#  <__main__.Card at 0x7fd8b14028e0>,
#  <__main__.Card at 0x7fd8b0983d90>,
#  <__main__.Card at 0x7fd8b0983790>,
#  <__main__.Card at 0x7fd8b09833a0>,
#  <__main__.Card at 0x7fd8b0983550>,
#  <__main__.Card at 0x7fd8b0983370>,
#  <__main__.Card at 0x7fd8b0983d60>,
#  <__main__.Card at 0x7fd8b09835e0>,
#  <__main__.Card at 0x7fd8b0983eb0>,
#  <__main__.Card at 0x7fd8b0983a00>,
#  <__main__.Card at 0x7fd8b0983040>,
#  <__main__.Card at 0x7fd8b0983a60>,
#  <__main__.Card at 0x7fd8b0983460>,
#  <__main__.Card at 0x7fd8b09836d0>,
#  <__main__.Card at 0x7fd8b09836a0>,
#  <__main__.Card at 0x7fd8b0983730>,
#  <__main__.Card at 0x7fd8b0983d00>,
#  <__main__.Card at 0x7fd8b09837f0>,
#  <__main__.Card at 0x7fd8b0983520>,
#  <__main__.Card at 0x7fd8b09838b0>,
#  <__main__.Card at 0x7fd8b0983fa0>,
#  <__main__.Card at 0x7fd8b0983c70>,
#  <__main__.Card at 0x7fd8b0dc4880>,
#  <__main__.Card at 0x7fd8b0dc4a90>,
#  <__main__.Card at 0x7fd8b0dc4940>,
#  <__main__.Card at 0x7fd8b0dc4760>,
#  <__main__.Card at 0x7fd8b0dc4b50>,
#  <__main__.Card at 0x7fd8b0dc4850>,
#  <__main__.Card at 0x7fd8b0dc4ac0>,
#  <__main__.Card at 0x7fd8b0dc4c70>,
#  <__main__.Card at 0x7fd8b0dc41c0>,
#  <__main__.Card at 0x7fd8b0dc4af0>,
#  <__main__.Card at 0x7fd8b0dc4bb0>,
#  <__main__.Card at 0x7fd8b0dc4a30>,
#  <__main__.Card at 0x7fd8b1309160>,
#  <__main__.Card at 0x7fd8b1309b80>,
#  <__main__.Card at 0x7fd8b13093d0>,
#  <__main__.Card at 0x7fd8b1309370>,
#  <__main__.Card at 0x7fd8b13095b0>,
#  <__main__.Card at 0x7fd8b1309340>,
#  <__main__.Card at 0x7fd8b13092b0>,
#  <__main__.Card at 0x7fd8b13097c0>,
#  <__main__.Card at 0x7fd8b1309850>,
#  <__main__.Card at 0x7fd8b13096d0>,
#  <__main__.Card at 0x7fd8b13090d0>,
#  <__main__.Card at 0x7fd8b1309430>,
#  <__main__.Card at 0x7fd8b1309580>,
#  <__main__.Card at 0x7fd8b1309730>,
#  <__main__.Card at 0x7fd8c0878130>,
#  <__main__.Card at 0x7fd8c0878d00>]

# %%
first_card2 = new_deck2.all_cards[0]

# %%
first_card2.value
# Out:
# 2

# %%
bottom_card2 = new_deck2.all_cards[-1]

# %%
print(bottom_card2)
# Out:
# Ace of Clubs

# %%
# shuffle new deck 2

new_deck2.shuffle()

# %%
print(new_deck2.all_cards[-1])
# Out:
# Four of Spades

# %% [markdown]
# ***

# %%
# Method to grab one of the cards from the list

# %%
class Deck():
    
    def __init__(self):
        
        # deck should contain all 52 card objects
        self.all_cards = [] # this is an attribute 
                            # this starts off as an empty list
        
        # for al suits, create a rank
        for suit in suits   :
            for rank in ranks:
                
                #Create the card object
                
                created_card = Card(suit,rank)
                
                # Append the newely created card to the list
                self.all_cards.append(created_card)
    
    def shuffle(self):
        
        # remember that random.shuffle does not return anything
        # there is not return -- it is all in place
        
        random.shuffle(self.all_cards)
    
    def deal_one(self):
        
        #return a single card
        return self.all_cards.pop()

# %%
new_deck3 = Deck()

# %%
new_deck3.shuffle()

# %%
mycard = new_deck3.deal_one()

# %%
mycard

# %%
print(mycard)
# Out:
# King of Spades

# %%
len(new_deck3.all_cards)
# Out:
# 51

# %%
# we have now permanently affecting the deck by removing the card
