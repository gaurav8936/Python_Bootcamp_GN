# %% [markdown]
# <font size = 8> Python Debugger

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %%
# Debugging using PRINT statements

# %% [markdown]
# ***

# %%
x = [1,2,3]
y = 2
z = 3

result = y + z

result2 = x + y
# here you are trying to add a list to an integer -- hence the error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#       3 z = 3
#       5 result = y + z
# ----> 7 result2 = x + y
#
# TypeError: can only concatenate list (not "int") to list

# %%
x = [1,2,3]
y = 2
z = 3

result = y + z
print(result)

result2 = x + y
print(y)
print(result2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 8>()
#       5 result = y + z
#       6 print(result)
# ----> 8 result2 = x + y
#       9 print(y)
#      10 print(result2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
# however this approach is limited

# %% [markdown]
# ***

# %%
# Using the Python DEBUGGER

# %% [markdown]
# ***

# %%
x = [1,2,3]
y = 2
z = 3

# %%
import pdb # python debugger

# %%
# x = [1,2,3]
# y = 2
# z = 3

# result_one  = y + z

# result_two = y + x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       3 z = 3
#       5 result_one  = y + z
# ----> 7 result_two = y + x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %% [markdown]
# ***

# %%
# Set trace using the debugger

# %%
x = [1,2,3]
y = 2
z = 3

result_one  = y + z


# Set trace before the error line

pdb.set_trace()

result_two = y + x
# Out:
# --Return--
# None
# > /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_69485/191985088.py(10)<cell line: 10>()
#       8 # Set trace before the error line
#       9
# ---> 10 pdb.set_trace()
#      11
#      12 result_two = y + x
#
# ipdb> x
# [1, 2, 3]
# ipdb> y
# 2
# ipdb> result_one
# 5
# ipdb> y
# 2
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# Input In [3], in <cell line: 10>()
#       5 result_one  = y + z
#       8 # Set trace before the error line
# ---> 10 pdb.set_trace()
#      12 result_two = y + x
#
# File ~/opt/anaconda3/lib/python3.9/bdb.py:92, in Bdb.trace_dispatch(self, frame, event, arg)
#      90     return self.dispatch_call(frame, arg)
#      91 if event == 'return':
# ---> 92     return self.dispatch_return(frame, arg)
#      93 if event == 'exception':
#      94     return self.dispatch_exception(frame, arg)
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# you can also perform math operations in the debugger

# %% [markdown]
# ***

# %%
# ENTER Q --- to quit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
