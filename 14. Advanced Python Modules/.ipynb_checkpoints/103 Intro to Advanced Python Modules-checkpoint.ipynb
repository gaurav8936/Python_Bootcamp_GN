# %% [markdown]
# <font size = 8> Intro to Advanced Python Modules

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# come prepackaged with Python

# %% [markdown]
# ![image.png](attachment:image.png)
