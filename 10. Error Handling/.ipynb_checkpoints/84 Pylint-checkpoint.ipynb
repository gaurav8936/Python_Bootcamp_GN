# %% [markdown]
# <font size = 8> Pylint Overview

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PEP 8 - Just a note -- not below section

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Check the PROBLEMs tab in VSCODE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### perfect score is 10/10 -- we scored minus 12.5 (horrible)

# %%
# It is pretty difficult to get 10/10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## after changes, the score is now +8.33 / 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the lecture had a different issue with indentation

# %%
# the issue is with mixed indentation

# %% [markdown]
# ## Check for SPACES or TABs -- this could be an issue
