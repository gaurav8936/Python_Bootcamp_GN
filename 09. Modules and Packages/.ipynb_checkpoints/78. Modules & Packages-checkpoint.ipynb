# %% [markdown]
# <font size = 8> Modules and Packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Modules are just .py script that you can call in another .py script

# %%
# Packages are a collection of modules

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Creating folders and having Python recognize them as packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Create two __init__.py files

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
