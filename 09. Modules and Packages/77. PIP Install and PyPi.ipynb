# %% [markdown]
# <font size = 8> PIP Install and PyPi

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# RubyGems for Ruby

# %%
# Packagist for PHP

# %%
# CPAN for Perl

# %%
# NPM for Node.js

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Django and Flask for are for Web Development with Python

# %% [markdown]
# <font color = red> Django and Flask for are for Web Development with Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Python Kernels on my Mac

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# PYTHON 3.8.2
# usr/bin/python3


#BASE
# /Users/ganarasi/opt/anaconda3/bin/python


# PYTHON 2.7.16
# DNU -- cant find this in the directory
# /usr/bin/python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The request package allows you to request packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The colorama library

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Remember quit is quit()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)
