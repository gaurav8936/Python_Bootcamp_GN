# %% [markdown]
# # Strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# uses single or double quotes -- sequence of strings

# %% [markdown]
# " U don't do that"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Strings are ordered sequences -- allows us to grab sub sections of the string

# %% [markdown]
# <font color='red'>text Indexing is to grab a single character from the string </font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Maybe you wanted to gran the last character of the string but did not know the lenght
# hence doing a -1 allows you to start from the right

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Slicing graba section of the string
# user the same square bracket

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %%
'thsi is also a string'
# Out:
# 'thsi is also a string'

# %% [markdown]
# ### white spaces count as characters

# %%
'I'm going on a run'
# Out:
#   Input In [4]
#     'I'm going on a run'
#        ^
# SyntaxError: invalid syntax

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %%
print("hello")
# Out:
# hello

# %%
"hello world one"
"hello world two"
# Out:
# 'hello world two'

# %% [markdown]
# In this case, notice that you only see the second line
# this is the difference between Out and print

# %%
print("hello 1")
print ("hello 2")
# Out:
# hello 1
# hello 2

# %%
print ('hello world')
# Out:
# hello world

# %% [markdown]
# ## escape sequence

# %%
print ("hello \n world")
# Out:
# hello
#  world

# %%
print ("hello \nworld")
# Out:
# hello
# world

# %%
print ("hello \t world")
# Out:
# hello 	 world

# %%
len("hello")
# Out:
# 5

# %%
len ("hello world")
# Out:
# 11
