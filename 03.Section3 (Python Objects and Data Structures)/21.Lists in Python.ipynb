# %% [markdown]
# # Lists in Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size = 16, color = green> Lists are like strings in that they support indexing and slicing <font>

# %%
my_list = [1,2,3]

# %%
print (my_list)
# Out:
# [1, 2, 3]

# %%
my_list = ['STRING', 100, 23.1]

# %%
len(my_list)
# Out:
# 3

# %%
print(my_list)
# Out:
# ['STRING', 100, 23.1]

# %% [markdown]
# ` the reason we can use indexing and slicing is that just like a string, lists are ordered sequences `

# %%
my_list = ['one', 'two', 'three']

# %% [markdown]
# ## Indexing

# %%
my_list[0]
# Out:
# 'one'

# %% [markdown]
# ## Slicing

# %%
my_list[1:]
# Out:
# ['two', 'three']

# %%
another_list = ['four', 'five']

# %% [markdown]
# ## Concatanating lists

# %%
my_list + another_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
my_list
# Out:
# ['one', 'two', 'three']

# %%
new_list = my_list + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# <font size = 12, color = 'cyan'> The big difference when compated to strings is that Lists can mutate <font>

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %% [markdown]
# ### Adding an element at the end of a list

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.append('seven')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six', 'seven']

# %% [markdown]
# ### Removing items from the list

# %%
new_list.pop()
# Out:
# 'seven'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %% [markdown]
# ### pop has removed hte last item

# %%
popped_item = new_list.pop()

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
new_list.pop(1)
# Out:
# 'two'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'three', 'four', 'five']

# %% [markdown]
# ###  <font color = 'red'> Sort Method <font>

# %%
new_list2 = ['a', 'g','h', 'y', 'u', 'j']
num_list2 = [4,3,1,3,5,7,8,9]

# %%
new_list2.sort()

# %% [markdown]
# #### sort is an 'IN PLACE' method and does not return anything

# %%
new_list2
# Out:
# ['a', 'g', 'h', 'j', 'u', 'y']

# %% [markdown]
# #### just that when you call the variable again, it is sorted

# %%
my_sorted_list = new_list2.sort()

# %%
print(my_sorted_list)
# Out:
# None

# %%
type(my_sorted_list)
# Out:
# NoneType

# %% [markdown]
# #### NONE Object -- indicates no value -- often used as a placeholder -- common default return value

# %%
new_list2.sort()
my_sorted_list = new_list2

# %%
my_sorted_list
# Out:
# ['a', 'g', 'h', 'j', 'u', 'y']

# %%
num_list2
# Out:
# [4, 3, 1, 3, 5, 7, 8, 9]

# %%
num_list2.sort()

# %%
num_list2
# Out:
# [1, 3, 3, 4, 5, 7, 8, 9]

# %% [markdown]
# ### <font color = 'red'> Reverse Method <font>

# %%
num_list2.reverse()

# %%
num_list2
# Out:
# [9, 8, 7, 5, 4, 3, 3, 1]

# %% [markdown]
# ` this is the opposite of sort `

# %% [markdown]
# ### Indexing a nested list

# %% [markdown]
# 1. How do I index a nested list? For example if I want to grab 2 from [1,1,[1,2]]?

# %%
new_list2 = [1,1,[1,2]]

# %%
new_list2[2][1]
# Out:
# 2
