# %% [markdown]
# <font size = 8> Decorator Homework

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Flask allows you to create webpages in Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# DJANGO is more HEAVY DUTY than Flask

# %% [markdown]
# <font size = 5, color = red> Difference between Framework and Library/API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# <font size = 5, color = red> Pinterest and Reddit developed with Python
