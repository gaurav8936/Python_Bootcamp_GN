# %% [markdown]
# <font size = 20, color = blue> Booleans <font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
True
# Out:
# True

# %% [markdown]
# ### Note the capitalization

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
False
# Out:
# False

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %% [markdown]
# ## Use the none keyword as a placeholder for which we will assign a value in the future

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
b = None

# %%
b
