# %% [markdown]
# # Variable Assignments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ` avoid words like list or str `

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# you can reassignmen variables to different data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# here my_dogs is assigned to two totally different data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### you do not have to define the data type

# %%
a  = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a = a + a

# %% [markdown]
# this is an example of reassignments

# %%
a
# Out:
# 20

# %%
a
# Out:
# 20

# %%
a
# Out:
# 20

# %%
a = a+a

# %%
a
# Out:
# 40

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a+a
# Out:
# 80

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a+a
# Out:
# 80

# %%
a
# Out:
# 40

# %%
type(a)
# Out:
# int

# %% [markdown]
# this is to identify the type

# %%
a=30.1

# %%
type(a)
# Out:
# float

# %% [markdown]
# ## float

# %%
int = 4

# %% [markdown]
# note the syntax is being highlighted

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# 5

# %%
my_income = 100
tax_rate  = 0.1
my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0
