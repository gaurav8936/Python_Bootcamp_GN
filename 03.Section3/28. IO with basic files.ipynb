# %% [markdown]
# <font size = 20, color = 'purple'> I/O with Basic Files in Python <font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Basic concepts for using all types of files

# %%
# %%writefile myfile.txt
# Hello this is a text file
# This is the second line
# This is the third line
# Out:
# Writing myfile.txt

# %% [markdown]
# ## The magic function works only for Jupyter Notebook -- not on Sublime etc

# %%
myfile = open('myfile.txt')

# %% [markdown]
# ### The fact there is no error means the file is there

# %%
myfile = open('wrongfile.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 myfile = open('wrongfile.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wrongfile.txt'

# %%
pwd
# Out:
# '/Users/ganarasi/Dropbox/Berkeley2022/00.Python/31.Python_Bootcamp_GN/03.Section3'

# %% [markdown]
# This is the working directory

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %% [markdown]
# #### the read method returns a giant dump of all the data in the text file -- not very practical at times

# %% [markdown]
# \n representa a new line -- escape sequence

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# ### The output is "" because the cursor has to be reset (it is now at the end of the file

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'This is the second line\n',
#  'This is the third line\n']

# %% [markdown]
# ### see the readlines method

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myfile2 = open("/Users/ganarasi/Dropbox/Berkeley2022/00.Python/31.Python_Bootcamp_GN/98.Reference/myfile2.txt")

# %%
myfile2.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
content = myfile2.read()

# %%
myfile2.seek(0)
# Out:
# 0

# %%
content = myfile2.read()

# %%
content
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile2.seek(0)
# Out:
# 0

# %%
myfile2.readlines()
# Out:
# ['Hello this is a text file\n',
#  'This is the second line\n',
#  'This is the third line\n']

# %% [markdown]
# ### remember to close the file upon opening

# %%
myfile.close()

# %%
myfile2.close()

# %% [markdown]
# ### use the WITH method as that closes the file automatically

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'
