# %% [markdown]
# <font size = 30> Chaining Comparison Operators <font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1<2
# Out:
# True

# %%
2<3
# Out:
# True

# %% [markdown]
# You can manually chain two of them

# %%
1<2<3
# Out:
# True

# %% [markdown]
# ## And

# %% [markdown]
# Use logical AND instead

# %%
1<2 and 2<3
# Out:
# True

# %%
'h' == 'h' and 2 == 2
# Out:
# True

# %% [markdown]
# ` Using paranthesis `

# %%
('h' == 'h') and (2 ==2)
# Out:
# True

# %% [markdown]
# ## Or

# %%
1 ==1 or 2 == 3
# Out:
# True

# %% [markdown]
# ## Not

# %%
not(1==1)
# Out:
# False

# %% [markdown]
# ` returns the opposite boolean `

# %%
not 1 == 1
# Out:
# False

# %%
400 > 5000
# Out:
# False

# %%
not(400>5000)
# Out:
# True
