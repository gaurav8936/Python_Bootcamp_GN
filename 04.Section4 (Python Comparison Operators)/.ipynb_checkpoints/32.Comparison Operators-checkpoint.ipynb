# %% [markdown]
# <font size = 30> Comparison Operators <font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2 ==2
# Out:
# True

# %%
2 ==1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %% [markdown]
# ` when comparing strings, capitalization counts `

# %%
'Hello' == 'hello'
# Out:
# False

# %%
'2' == 2
# Out:
# False

# %% [markdown]
# ` note the way floating point comparisons work `

# %%
2.0 ==2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
2>1
# Out:
# True

# %%
1>2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
2>= 3
# Out:
# False

# %%
4 <= 1
# Out:
# False
